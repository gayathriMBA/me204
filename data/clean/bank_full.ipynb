# %% [markdown]
# The bank introduce the "AUTO INSURANCE POLICY" promoting through "EMAIL,WEBSITE"

# %%
#! pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("E:/DSM/data/bank-full.csv")

# %%
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  Target     45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome Target
# 0  unknown    5   may       261         1     -1         0  unknown     no
# 1  unknown    5   may       151         1     -1         0  unknown     no
# 2  unknown    5   may        76         1     -1         0  unknown     no
# 3  unknown    5   may        92         1     -1         0  unknown     no
# 4  unknown    5   may       198         1     -1         0  unknown     no

# %%
df.describe(include='object')
# Out:
#                 job  marital  education default housing   loan   contact  \
# count         45211    45211      45211   45211   45211  45211     45211
# unique           12        3          4       2       2      2         3
# top     blue-collar  married  secondary      no     yes     no  cellular
# freq           9732    27214      23202   44396   25130  37967     29285
#
#         month poutcome Target
# count   45211    45211  45211
# unique     12        4      2
# top       may  unknown     no
# freq    13766    36959  39922

# %%
df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
df.shape
# Out:
# (45211, 17)

# %%
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %% [markdown]
# the TARGET variable indicate the customer conversion (convert=yes,non_convert=no)

# %%
df['conversion']= df['Target'].apply (lambda x:0 if x == 'no' else 1)

# %%
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df['conversion']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 45206    1
# 45207    1
# 45208    1
# 45209    0
# 45210    0
# Name: conversion, Length: 45211, dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'Target', 'conversion'],
#       dtype='object')

# %% [markdown]
# conversion rate
# marital,job plot
# default base -conversion rate(pivottable)

# %% [markdown]
# # Encoding Categorical Variables

# %%
months = ['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec']

# %%
df['month']=df['month'].apply(lambda x: months.index(x)+1)

# %%
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %% [markdown]
# job,m,h,l encode

# %%
df['housing']=df['housing'].apply(lambda x: 1 if x == 1 else 0 )

# %%
df
# Out:
#        age           job   marital  education default  balance  housing loan  \
# 0       58    management   married   tertiary      no     2143        0   no
# 1       44    technician    single  secondary      no       29        0   no
# 2       33  entrepreneur   married  secondary      no        2        0  yes
# 3       47   blue-collar   married    unknown      no     1506        0   no
# 4       33       unknown    single    unknown      no        1        0   no
# ...    ...           ...       ...        ...     ...      ...      ...  ...
# 45206   51    technician   married   tertiary      no      825        0   no
# 45207   71       retired  divorced    primary      no     1729        0   no
# 45208   72       retired   married  secondary      no     5715        0   no
# 45209   57   blue-collar   married  secondary      no      668        0   no
# 45210   37  entrepreneur   married  secondary      no     2971        0   no
#
# ...

# %%
df['loan']=df['loan'].apply(lambda x: 1 if x == 1 else 0 )

# %%
df
# Out:
#        age           job   marital  education default  balance  housing  loan  \
# 0       58    management   married   tertiary      no     2143        0     0
# 1       44    technician    single  secondary      no       29        0     0
# 2       33  entrepreneur   married  secondary      no        2        0     0
# 3       47   blue-collar   married    unknown      no     1506        0     0
# 4       33       unknown    single    unknown      no        1        0     0
# ...    ...           ...       ...        ...     ...      ...      ...   ...
# 45206   51    technician   married   tertiary      no      825        0     0
# 45207   71       retired  divorced    primary      no     1729        0     0
# 45208   72       retired   married  secondary      no     5715        0     0
# 45209   57   blue-collar   married  secondary      no      668        0     0
# 45210   37  entrepreneur   married  secondary      no     2971        0     0
#
# ...

# %% [markdown]
# ## Encoding for job

# %%
df['job'].unique()
# Out:
# array(['management', 'technician', 'entrepreneur', 'blue-collar',
#        'unknown', 'retired', 'admin.', 'services', 'self-employed',
#        'unemployed', 'housemaid', 'student'], dtype=object)

# %%
#job_encoded_df = pd.get_dummies(df['job'],dtype=int)
#job_encoded_df
#job_encoded_df.columns =['job_%s'% x for x in job_encoded_df.columns]

# %%
#job_encoded_df.head()

# %% [markdown]
# ## Encoding for Marital

# %%
df['job'].unique()
# Out:
# array(['management', 'technician', 'entrepreneur', 'blue-collar',
#        'unknown', 'retired', 'admin.', 'services', 'self-employed',
#        'unemployed', 'housemaid', 'student'], dtype=object)

# %%
#marital_encoded_df = pd.get_dummies(df['marital'],dtype=int)
#marital_encoded_df
#marital_encoded_df.columns =['marital_%s'% x for x in job_encoded_df.columns]

# %%
#marital_encoded_df.head()

# %% [markdown]
# # Encoding

# %%
encode_df=pd.get_dummies(df,columns=['job','marital'],dtype=int)
full_df=pd.concat([df,encode_df],axis=1)

# %%
full_df=full_df.loc[:,~full_df.columns.duplicated()]

# %%
df['housing']= df['housing'].apply(lambda x:1 if x=='yes' else 0)
df['loan']= df['loan'].apply(lambda x:1 if x=='yes' else 0)

# %%
list(full_df.columns)
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'balance',
#  'housing',
#  'loan',
#  'contact',
#  'day',
#  'month',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'Target',
#  'conversion',
#  'job_admin.',
#  'job_blue-collar',
#  'job_entrepreneur',
#  'job_housemaid',
#  'job_management',
#  'job_retired',
#  'job_self-employed',
#  'job_services',
#  'job_student',
#  'job_technician',
#  'job_unemployed',
#  'job_unknown',
#  'marital_divorced',
#  'marital_married',
#  'marital_single']

# %% [markdown]
# # decision tree

# %%
#! pip install scikit-learn

from sklearn import tree

# %%
response_var = 'conversion'
features = [
    'age','balance','campaign','previous','housing',
 'loan','job_management',
 'job_retired',
 'job_self-employed',
 'job_services',
 'job_student',
 'job_technician',
 'job_unemployed',
 'job_unknown',
 'marital_divorced',
 'marital_married',
 'marital_single'
]

# %%
dt_model = tree.DecisionTreeClassifier(
     max_depth=4  # depth code is for the 
)

# %%
dt_model
# Out:
# DecisionTreeClassifier(max_depth=4)

# %%
dt_model.fit(full_df[features],df[response_var])
# Out:
# DecisionTreeClassifier(max_depth=4)

# %%
dt_model.classes_
# Out:
# array([0, 1])

# %% [markdown]
# ## we identitfy which one is highly important in the variable so we use feature_importances  ( highly significant is age nama  features la variable store pannirukura order ladha varum yedha output pota adha variable )

# %%
dt_model.feature_importances_
# Out:
# array([0.36729377, 0.02761315, 0.01643517, 0.43040749, 0.        ,
#        0.        , 0.04242507, 0.        , 0.00334381, 0.        ,
#        0.04069696, 0.        , 0.        , 0.        , 0.00875935,
#        0.        , 0.06302523])

# %%
import matplotlib.pyplot as plt

#convert class names to strings
class_names = [str(label) for label in dt_model.classes_]

# %% [markdown]
# ##### previous(campaign)<=1 more than one campaign attend pannavaga rate is high , campaign less than 1 errukum bodhu less conversion rate
# ##### avoid blue-collor job , management and student job are more conversion , younger peoples based on job, marital  conversion rate is high.
# ##### Target younger individuals.  Prioritize those who have participated in multiple campaigns.Focus on specific job roles like management and students while avoiding blue-collar workers.

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(dt_model,feature_names=features,class_names=class_names,filled=True)
plt.show()
